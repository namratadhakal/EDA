# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing the csv file

# %%
df = pd.read_csv('sleep_health_lifestyle_dataset.csv')

# %%
df.shape
# Out:
# (400, 13)

# %% [markdown]
# DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Person ID                              400 non-null    int64
#  1   Gender                                 399 non-null    object
#  2   Age                                    400 non-null    int64
#  3   Occupation                             399 non-null    object
#  4   Sleep Duration (hours)                 400 non-null    float64
#  5   Quality of Sleep (scale: 1-10)         399 non-null    float64
#  6   Physical Activity Level (minutes/day)  400 non-null    int64
#  7   Stress Level (scale: 1-10)             400 non-null    int64
#  8   BMI Category                           400 non-null    object
#  9   Blood Pressure (systolic/diastolic)    400 non-null    object
# ...

# %%
df.dropna(axis=0,inplace=True)   ## dropna drops all the null value and axis= 0 represent x-axis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 4 to 398
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Person ID                              108 non-null    int64
#  1   Gender                                 108 non-null    object
#  2   Age                                    108 non-null    int64
#  3   Occupation                             108 non-null    object
#  4   Sleep Duration (hours)                 108 non-null    float64
#  5   Quality of Sleep (scale: 1-10)         108 non-null    float64
#  6   Physical Activity Level (minutes/day)  108 non-null    int64
#  7   Stress Level (scale: 1-10)             108 non-null    int64
#  8   BMI Category                           108 non-null    object
#  9   Blood Pressure (systolic/diastolic)    108 non-null    object
#  10  Heart Rate (bpm)                       108 non-null    int64
# ...

# %%
df.head()
# Out:
#     Person ID  Gender  Age     Occupation  Sleep Duration (hours)  \
# 4           5    Male   67        Retired                     9.1
# 8           9    Male   25   Manual Labor                    11.9
# 12         13    Male   54  Office Worker                     4.1
# 18         19  Female   26   Manual Labor                     9.2
# 19         20    Male   27   Manual Labor                    10.6
#
#     Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# 4                              9.5                                     19
# 8                              7.2                                     27
# 12                             6.8                                    113
# 18                             6.4                                     93
# 19                             8.1                                     94
#
#     Stress Level (scale: 1-10) BMI Category  \
# 4                            4   Overweight
# ...

# %%
pd.isnull(df).sum()  ## checking whether their is any null value in any column collectively
# Out:
# Person ID                                0
# Gender                                   0
# Age                                      0
# Occupation                               0
# Sleep Duration (hours)                   0
# Quality of Sleep (scale: 1-10)           0
# Physical Activity Level (minutes/day)    0
# Stress Level (scale: 1-10)               0
# BMI Category                             0
# Blood Pressure (systolic/diastolic)      0
# Heart Rate (bpm)                         0
# Daily Steps                              0
# Sleep Disorder                           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration (hours)',
#        'Quality of Sleep (scale: 1-10)',
#        'Physical Activity Level (minutes/day)', 'Stress Level (scale: 1-10)',
#        'BMI Category', 'Blood Pressure (systolic/diastolic)',
#        'Heart Rate (bpm)', 'Daily Steps', 'Sleep Disorder'],
#       dtype='object')

# %%
df.rename(columns = {'Physical Activity Level (minutes/day)':'exercise(min/day)'})
# Out:
#      Person ID  Gender  Age     Occupation  Sleep Duration (hours)  \
# 4            5    Male   67        Retired                     9.1
# 8            9    Male   25   Manual Labor                    11.9
# 12          13    Male   54  Office Worker                     4.1
# 18          19  Female   26   Manual Labor                     9.2
# 19          20    Male   27   Manual Labor                    10.6
# ..         ...     ...  ...            ...                     ...
# 392        393  Female   18   Manual Labor                     8.2
# 395        396  Female   36        Student                     4.5
# 396        397  Female   45   Manual Labor                     6.0
# 397        398  Female   30        Student                     5.3
# 398        399  Female   41        Retired                    11.0
#
#      Quality of Sleep (scale: 1-10)  exercise(min/day)  \
# 4                               9.5                 19
# ...

# %%
df.describe()
# Out:
#         Person ID        Age  Sleep Duration (hours)  \
# count  108.000000  108.00000              108.000000
# mean   197.407407   39.87037                8.175000
# std    121.439269   14.43522                2.487882
# min      5.000000   18.00000                4.100000
# 25%     92.000000   29.50000                5.800000
# 50%    191.500000   40.00000                8.900000
# 75%    298.250000   47.25000               10.225000
# max    399.000000   90.00000               12.000000
#
#        Quality of Sleep (scale: 1-10)  Physical Activity Level (minutes/day)  \
# count                      108.000000                             108.000000
# mean                         6.163889                              57.462963
# std                          1.811307                              30.745998
# min                          1.000000                              11.000000
# 25%                          5.100000                              29.000000
# ...

# %% [markdown]
# ##EXPLORATORY DATA ANALYSIS
